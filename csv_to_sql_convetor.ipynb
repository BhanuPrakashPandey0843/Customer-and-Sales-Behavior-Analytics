# %%
import pandas as pd
import mysql.connector
import os

# List of CSV files and corresponding table names
csv_files = [
    ('customers.csv', 'customers'),
    ('orders.csv', 'orders'),
    ('sellers.csv', 'sellers'),
    ('products.csv', 'products'),
    ('delivery.csv', 'delivery'),
    ('payments.csv', 'payments'),
    ('order_items.csv', 'order_items')
]

# MySQL connection
conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='Bhanu0843@',
    database='ecommerce'
)
cursor = conn.cursor()

# Folder path
folder_path = 'E:/Data Analysis/E-Commerce/Dataset'

# Function to map pandas dtypes to SQL types
def get_sql_type(dtype):
    if pd.api.types.is_integer_dtype(dtype):
        return 'INT'
    elif pd.api.types.is_float_dtype(dtype):
        return 'FLOAT'
    elif pd.api.types.is_bool_dtype(dtype):
        return 'BOOLEAN'
    elif pd.api.types.is_datetime64_any_dtype(dtype):
        return 'DATETIME'
    else:
        return 'TEXT'

# Loop through each file and process
for csv_file, table_name in csv_files:
    file_path = os.path.join(folder_path, csv_file)

    if not os.path.exists(file_path):
        print(f"⚠️ File not found: {file_path}")
        continue

    print(f"📥 Processing: {csv_file}")

    # Load CSV with header handling and clean data
    df = pd.read_csv(file_path, header=0, skip_blank_lines=True)

    # Drop columns with all NaN values
    df.dropna(axis=1, how='all', inplace=True)

    # Clean and sanitize column names
    df.columns = [str(col).strip().replace(' ', '_').replace('-', '_').replace('.', '_') for col in df.columns]
    df.columns = ['col_' + str(i) if str(col).lower() == 'nan' else col for i, col in enumerate(df.columns)]

    # Debug: Show column names
    print(f"📊 Columns in `{table_name}`: {df.columns.tolist()}")

    # Replace NaN with None for SQL NULL
    df = df.where(pd.notnull(df), None)

    # Drop table if it exists (to avoid structure mismatch)
    cursor.execute(f"DROP TABLE IF EXISTS `{table_name}`")

    # Create table
    column_definitions = ', '.join([f'`{col}` {get_sql_type(dtype)}' for col, dtype in df.dtypes.items()])
    create_table_query = f"CREATE TABLE `{table_name}` ({column_definitions})"
    cursor.execute(create_table_query)

    # Prepare INSERT query
    placeholders = ', '.join(['%s'] * len(df.columns))
    insert_query = f"INSERT INTO `{table_name}` ({', '.join(['`' + col + '`' for col in df.columns])}) VALUES ({placeholders})"

    # Insert rows
    inserted_rows = 0
    for row in df.itertuples(index=False, name=None):
        try:
            cursor.execute(insert_query, row)
            inserted_rows += 1
        except Exception as e:
            print(f"❌ Error inserting into `{table_name}`: {e}")
            print(f"⛔ Problematic row: {row}")

    # Commit changes for this table
    conn.commit()
    print(f"✅ Inserted {inserted_rows} records into `{table_name}`.\n")

# Close connections
cursor.close()
conn.close()
print("🎉 All done! MySQL connection closed.")
# Out:
# 📥 Processing: customers.csv
# 📊 Columns in `customers`: ['customer_id', 'customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state']
# ✅ Inserted 99441 records into `customers`.
#
# 📥 Processing: orders.csv
# 📊 Columns in `orders`: ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']
# ✅ Inserted 99441 records into `orders`.
#
# 📥 Processing: sellers.csv
# 📊 Columns in `sellers`: ['seller_id', 'seller_zip_code_prefix', 'seller_city', 'seller_state']
# ✅ Inserted 3095 records into `sellers`.
#
# 📥 Processing: products.csv
# 📊 Columns in `products`: ['product_id', 'product_category', 'product_name_length', 'product_description_length', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm']
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('a41e356c76fab66334f36de622ecbd3a', None, nan, nan, nan, 650.0, 17.0, 14.0, 12.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('d8dee61c2034d6d075997acef1870e9b', None, nan, nan, nan, 300.0, 16.0, 7.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('56139431d72cd51f19eb9f7dae4d1617', None, nan, nan, nan, 200.0, 20.0, 20.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('46b48281eb6d663ced748f324108c733', None, nan, nan, nan, 18500.0, 41.0, 30.0, 41.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('5fb61f482620cb672f5e586bb132eae9', None, nan, nan, nan, 300.0, 35.0, 7.0, 12.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('e10758160da97891c2fdcbc35f0f031d', None, nan, nan, nan, 2200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('39e3b9b12cd0bf8ee681bbc1c130feb5', None, nan, nan, nan, 300.0, 16.0, 7.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('794de06c32a626a5692ff50e4985d36f', None, nan, nan, nan, 300.0, 18.0, 8.0, 14.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('7af3e2da474486a3519b0cba9dea8ad9', None, nan, nan, nan, 200.0, 22.0, 14.0, 14.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('629beb8e7317703dcc5f35b5463fd20e', None, nan, nan, nan, 1400.0, 25.0, 25.0, 25.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('3a78f64aac654298e4b9aff32fc21818', None, nan, nan, nan, 4300.0, 30.0, 10.0, 48.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('bcb815bba008d89458e428078c0b9211', None, nan, nan, nan, 150.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('6b82874c6b51b92913dcdb364eaaae0f', None, nan, nan, nan, 21450.0, 70.0, 34.0, 50.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('c68b419d9c6038271b85bac98adb0fc9', None, nan, nan, nan, 1000.0, 16.0, 14.0, 30.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('1dcd65bb5dd967d7b4c6b0223cefb838', None, nan, nan, nan, 9150.0, 33.0, 30.0, 44.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('671446e8e3aa3df1eca47b6c354a2921', None, nan, nan, nan, 5500.0, 33.0, 22.0, 33.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('f0ea71b6e2ab4cb3bd8f5ba522a25a56', None, nan, nan, nan, 1300.0, 30.0, 20.0, 30.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('fedccbd5e370e8ddb7aae6fb4cb70347', None, nan, nan, nan, 1200.0, 20.0, 20.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('212cc0fa7359ab242a697a03a574f719', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('6b7879a37ac2dbe5289a16706e859870', None, nan, nan, nan, 950.0, 45.0, 12.0, 30.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('44e8945e17aef03daaecbc4bbab7f730', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('3abf2d4698bf245577543ea01d9c7f16', None, nan, nan, nan, 200.0, 22.0, 14.0, 14.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('ca26080d8f0fa848c329fe732f5e34e8', None, nan, nan, nan, 1800.0, 25.0, 25.0, 25.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('1a2ece70966710dec441aa587993b5b4', None, nan, nan, nan, 300.0, 27.0, 5.0, 18.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('5f4bceafafc1903556735cb7f2842e78', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b61d1388a17e3f547d2bc218df02335b', None, nan, nan, nan, 350.0, 16.0, 6.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b9adb2d8377c195da59e75743dbb7133', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('ceeba7d5636e59173cc5f484e913db3d', None, nan, nan, nan, 30000.0, 65.0, 65.0, 65.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('7ce49c8945602088c4c4ca3e0ceb8244', None, nan, nan, nan, 1400.0, 35.0, 3.0, 35.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('0533c5ec3a042521493cfb6e12d6befd', None, nan, nan, nan, 1550.0, 38.0, 4.0, 23.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('9f69acd4da62618a3f6365b732d00ccd', None, nan, nan, nan, 850.0, 27.0, 13.0, 21.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('19f3b74026e6ec6c83fc25e21baf454e', None, nan, nan, nan, 1300.0, 52.0, 10.0, 38.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('0fa699aaa0a38aa5d1de8e7fe04d2204', None, nan, nan, nan, 17900.0, 48.0, 32.0, 28.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('94c07760f470ab9997f27d0129682eb3', None, nan, nan, nan, 450.0, 16.0, 20.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('3f6f946481fd39f4eda986012f6e0447', None, nan, nan, nan, 1600.0, 38.0, 28.0, 40.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('a9d8f831888820cd641dcd5ca9fea4e8', None, nan, nan, nan, 50.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('48270bcc7097939dcf14a537d7128054', None, nan, nan, nan, 1000.0, 30.0, 30.0, 30.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b5778c55de68777a0a3565e03b2e2817', None, nan, nan, nan, 2500.0, 26.0, 25.0, 47.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('51fe26bc4bb0f89f07096d8c96b35476', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('9ce62e73b4ea1a6c74b68ba57aa1333b', None, nan, nan, nan, 1000.0, 31.0, 21.0, 24.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('fbd2a9aa1f115244e2ce115ad8eacfca', None, nan, nan, nan, 1200.0, 33.0, 2.0, 27.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('ab1741a86f20ab3aca7dd2c347d5a9e3', None, nan, nan, nan, 3600.0, 39.0, 10.0, 35.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('fa7fc74ae3858461908b3503b355fd5e', None, nan, nan, nan, 17100.0, 42.0, 80.0, 30.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('014fcf6bd5cd4c7ee29fb3bb618c445e', None, nan, nan, nan, 7000.0, 55.0, 30.0, 45.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('be59f0b9bd1d08d096188f98168fc987', None, nan, nan, nan, 3550.0, 40.0, 10.0, 40.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('9f6e8441548dd40516cdb98f1b29c3d5', None, nan, nan, nan, 2700.0, 44.0, 13.0, 44.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('d73f1e4ad0322d8442fc9591505381aa', None, nan, nan, nan, 500.0, 35.0, 25.0, 35.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b17a4e7b997ea645dd323bb1bed802ac', None, nan, nan, nan, 600.0, 24.0, 4.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('8d39a63db6a98e40571f486e0c711cf7', None, nan, nan, nan, 450.0, 16.0, 7.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('1a1dba78177cbabf00a2e1eab46e62b6', None, nan, nan, nan, 700.0, 35.0, 35.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('3846c262ddb08db0ea2cc1a1685590ff', None, nan, nan, nan, 600.0, 18.0, 18.0, 18.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b3f3d2afe706552a90fd99f870e4ddf5', None, nan, nan, nan, 3000.0, 33.0, 40.0, 22.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('3e6092cf0f56b9c78bcbd539157b9f70', None, nan, nan, nan, 400.0, 17.0, 17.0, 17.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('8d3367004d60f40855db4a5bbbabfdb6', None, nan, nan, nan, 900.0, 22.0, 4.0, 14.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('09337f4d317bae01dfa96e6d368eafc4', None, nan, nan, nan, 800.0, 38.0, 10.0, 16.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('645fd9f79f14fad6e8a79fbc94dae528', None, nan, nan, nan, 5100.0, 30.0, 20.0, 30.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('39fda099b9edc21f85a80d14021579b5', None, nan, nan, nan, 300.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('6ad6cc284cdcc1cdd2f06eef8d983913', None, nan, nan, nan, 100.0, 22.0, 6.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('40a1e3c65a0bcf6f4ebba840a8156ba2', None, nan, nan, nan, 200.0, 16.0, 10.0, 13.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('a08ffa6ecdd0ab3c1f4fe348acc2553b', None, nan, nan, nan, 1000.0, 40.0, 8.0, 40.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('6fe7ef5f743e7b92a2c74264f40d0437', None, nan, nan, nan, 6100.0, 80.0, 5.0, 60.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b607bf5bab84cb38111d2b6a10164385', None, nan, nan, nan, 200.0, 16.0, 2.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('d1802b79d2e79841cc2cadedd8d4e6a3', None, nan, nan, nan, 900.0, 32.0, 10.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('aaa391b7c35a628a6318851e8e933e0b', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('3d103df80d5d22d709244fe27bc29a8d', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('73df0070248804951b5c6ba9537c6fc3', None, nan, nan, nan, 100.0, 16.0, 6.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('fb09c649a144a9dfd4546612891e1f11', None, nan, nan, nan, 2000.0, 38.0, 12.0, 38.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('c7858457bc43561ccb96aaa2932cb085', None, nan, nan, nan, 10750.0, 35.0, 65.0, 35.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('e9cbc0910ab050cbd92fbeb051c270ea', None, nan, nan, nan, 600.0, 32.0, 15.0, 28.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('0502d1a36be75bd36b452f31c6ed264a', None, nan, nan, nan, 100.0, 16.0, 7.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('bc0cf6f75f7db177ba3d47677f5e467f', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('8229dca25207625966da8cffda27446c', None, nan, nan, nan, 700.0, 24.0, 4.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('0a7a5763f6ee3b862ca27208f8fbbdb7', None, nan, nan, nan, 1000.0, 20.0, 15.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('eef398550dd9575d23eb2d8be74bd45a', None, nan, nan, nan, 1100.0, 35.0, 15.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('a61e6f38c9e407c7d764ea09d34b0a76', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('bf1ce2996ddec3052749c74b73b02b86', None, nan, nan, nan, 400.0, 18.0, 7.0, 17.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('52a5346c9dae9cd560b103875b94d123', None, nan, nan, nan, 200.0, 22.0, 14.0, 14.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('21e4321fa558327afe025bfb800a8bff', None, nan, nan, nan, 1500.0, 27.0, 8.0, 19.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('e49a57a6afd465b7d3cd109daf09ca98', None, nan, nan, nan, 220.0, 21.0, 11.0, 16.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('e64befe356dccc6ed0073c124147269f', None, nan, nan, nan, 200.0, 25.0, 5.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b02a3f9824b29932f36a74d811f1b14c', None, nan, nan, nan, 2500.0, 58.0, 18.0, 45.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('d64615580eb89e5d9a6ae0e37135a5fe', None, nan, nan, nan, 300.0, 16.0, 7.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('bfb85a2851757334da980ac9893a6261', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('60d1e2123927bc621354b0ab11cc8fd5', None, nan, nan, nan, 300.0, 16.0, 19.0, 16.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('73c5d3186138770b5ae53055adf10ad9', None, nan, nan, nan, 300.0, 78.0, 10.0, 22.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('a2d0e33d71561d8116565565a6f68578', None, nan, nan, nan, 150.0, 16.0, 16.0, 16.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('0ae10ca52e6cb8745e17c11e7c43907c', None, nan, nan, nan, 700.0, 30.0, 30.0, 30.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('1f5542855786adc0116f56cfd6f9f830', None, nan, nan, nan, 150.0, 20.0, 5.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('05cf9ac595f28386ee763c98cbc2bad0', None, nan, nan, nan, 150.0, 20.0, 3.0, 13.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('6868e3f08c6acd37b48c785aedddfdb7', None, nan, nan, nan, 1000.0, 29.0, 5.0, 27.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('86047e935e01608082bdae92e41a11db', None, nan, nan, nan, 1045.0, 30.0, 19.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('08a59a7c557b1b8d49e5029a337d83fd', None, nan, nan, nan, 400.0, 28.0, 6.0, 27.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('d6bcc9649c52a826c656563ffb87a036', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('2f282449dadb2e59ff2afcde0bd9f393', None, nan, nan, nan, 1600.0, 45.0, 25.0, 25.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('d7b39598905ba8e791fe3f1f376d59f9', None, nan, nan, nan, 200.0, 28.0, 9.0, 18.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('519693b7e29749ed7b6ad60cb07b9400', None, nan, nan, nan, 200.0, 25.0, 2.0, 18.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('0ed27993e016d4546e2038bfd75b812c', None, nan, nan, nan, 1000.0, 48.0, 8.0, 39.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('4257f45f6ea58aa46885ed7ef723b6c0', None, nan, nan, nan, 2300.0, 29.0, 13.0, 25.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('bb69b35babb38529a803d3f77d1e7454', None, nan, nan, nan, 850.0, 30.0, 20.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('242a6abd32d7630b48ef5c0a1bf527eb', None, nan, nan, nan, 400.0, 35.0, 16.0, 35.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('45a15b38cc3c0514717a1de673c6193c', None, nan, nan, nan, 250.0, 17.0, 8.0, 13.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('fcde1899043318107d8f0ae043f69bc3', None, nan, nan, nan, 400.0, 35.0, 7.0, 12.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('ed000a9f9f04376551e24de254464c9e', None, nan, nan, nan, 7400.0, 40.0, 6.0, 35.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('dc9f66a56b89e4278d921898a861a29a', None, nan, nan, nan, 200.0, 22.0, 3.0, 22.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('6627f494b45486e462e2bb460fcb18e5', None, nan, nan, nan, 445.0, 17.0, 12.0, 29.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('9df852a6c839bc3202227666d70c7cae', None, nan, nan, nan, 9150.0, 49.0, 32.0, 35.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('74ba0cd1f694e0751c7240443e5a038b', None, nan, nan, nan, 1000.0, 32.0, 3.0, 23.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('17b9f231d057710012fe28e5a1ac5186', None, nan, nan, nan, 10600.0, 40.0, 40.0, 30.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('9b6459fd1853c7e4422ff0bdd8184cb3', None, nan, nan, nan, 2000.0, 80.0, 60.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('46255a421f244cd985f138a63d77d09c', None, nan, nan, nan, 15500.0, 51.0, 50.0, 36.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('f58e45b16a42a325c144eb2c46a2bc57', None, nan, nan, nan, 6250.0, 28.0, 34.0, 40.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('71225f49be70df4297892f6a5fa62171', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('62fde58e97724f8b7519f3789eefa33f', None, nan, nan, nan, 600.0, 35.0, 35.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('db1d1a4569fdbae28a0d3340d907f7af', None, nan, nan, nan, 400.0, 16.0, 5.0, 12.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('194163a8a65a48a8c95623c399a9d4a7', None, nan, nan, nan, 1600.0, 48.0, 8.0, 39.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('cae7a908351ea0b7acb0086a51f6f565', None, nan, nan, nan, 400.0, 25.0, 7.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('31dbb0d1815bdc83c93f4b3472fa7c4d', None, nan, nan, nan, 300.0, 24.0, 24.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('6d0af4d8b482cc38d72acafc37bdd8f1', None, nan, nan, nan, 2400.0, 34.0, 33.0, 19.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('0103863bf3441460142ec23c74388e4c', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('7e005c651eec410691559257f9ef8f64', None, nan, nan, nan, 1200.0, 40.0, 10.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('15f773b4fea5b2ab681b02620b0c3a95', None, nan, nan, nan, 750.0, 16.0, 25.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b01cedfa96d891427058852f0625e9ee', None, nan, nan, nan, 4900.0, 42.0, 16.0, 37.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('9d09d82a6838777302175f209dcfc4ec', None, nan, nan, nan, 400.0, 16.0, 15.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('0082684bb4a60a862baaf7a60a5845ed', None, nan, nan, nan, 500.0, 24.0, 4.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('4f0aa1e91719362daf498003e6ad4177', None, nan, nan, nan, 1800.0, 20.0, 30.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('3373d1ed7bf5f3187f110c0e9e40a02b', None, nan, nan, nan, 200.0, 25.0, 5.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b20dff2518b593f3092fb7b3ba13588e', None, nan, nan, nan, 750.0, 30.0, 19.0, 18.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('cf1c83c0097bce11c715b94f292769b5', None, nan, nan, nan, 800.0, 20.0, 12.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('8c7274c4e638e7f229007fe28aafc741', None, nan, nan, nan, 1950.0, 40.0, 8.0, 30.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('a8e59319e3c44b5af3a5412d713af5bb', None, nan, nan, nan, 200.0, 16.0, 12.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('0b2f52bff0f8a4536a315bbdc34d8398', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('19bdfd05824c29bf495c9f5408c26635', None, nan, nan, nan, 1400.0, 40.0, 15.0, 40.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('c321936f167cdd14866ac591eea36f38', None, nan, nan, nan, 1300.0, 30.0, 10.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('1fde73e6b6d28627ff16e222b0044b10', None, nan, nan, nan, 500.0, 22.0, 11.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('00d62b338366db4c4aec8547ea8f928e', None, nan, nan, nan, 400.0, 24.0, 4.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('12ad6d9a5da40908f6741145e1a93443', None, nan, nan, nan, 5850.0, 36.0, 27.0, 54.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('14086fd4907ab4135efce70c2cd3c013', None, nan, nan, nan, 200.0, 22.0, 14.0, 14.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('817a68e75e8fc94fa28915d8169d67bf', None, nan, nan, nan, 800.0, 40.0, 5.0, 50.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('50f39d42ee3c1155a39f330b0b53c735', None, nan, nan, nan, 500.0, 16.0, 19.0, 12.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b5d80a1b72c94ff284760dabb4fb776b', None, nan, nan, nan, 400.0, 16.0, 15.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('82758517d6c9cc65c509781f1e14e9f2', None, nan, nan, nan, 900.0, 31.0, 13.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('c4d92c32b2e02363d3f087c7156a523c', None, nan, nan, nan, 800.0, 30.0, 13.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('ea11e700a343582ad56e4c70e966cb36', None, nan, nan, nan, 26000.0, 67.0, 57.0, 46.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('9820e04e332fc450d6fd975befc1bc28', None, nan, nan, nan, 10800.0, 40.0, 40.0, 30.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('96cadd6d137bc9726fe1fae279d48631', None, nan, nan, nan, 1300.0, 25.0, 15.0, 14.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('e275b12a1775bcc17af5524af5ba80b4', None, nan, nan, nan, 500.0, 35.0, 7.0, 40.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('ad113e2e3b77e66ef6ecfd7386cd13ac', None, nan, nan, nan, 1700.0, 16.0, 36.0, 13.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('ea8062a20ca055f459f3a99eccdec4b5', None, nan, nan, nan, 200.0, 22.0, 14.0, 14.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('a8cb589d0aa5e6308a8fcf133ecca711', None, nan, nan, nan, 990.0, 18.0, 27.0, 17.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('5455dbe20e64b08413e0f2c451e31ab9', None, nan, nan, nan, 700.0, 43.0, 7.0, 54.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('41f1e5a38185a9ae6090a552b712ba43', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('f9b1795281ce51b1cf39ef6d101ae8ab', None, nan, nan, nan, 400.0, 32.0, 15.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('06ddfdf210c7e0259854ee543215088d', None, nan, nan, nan, 100.0, 16.0, 3.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('270e70a55f9a0917f86b37cb32afcddd', None, nan, nan, nan, 300.0, 30.0, 6.0, 12.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('e891d4a9622cae3b9fc2ec558bda155b', None, nan, nan, nan, 400.0, 50.0, 5.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('e76828e87d341935c7d4e9f26420cda0', None, nan, nan, nan, 2250.0, 31.0, 19.0, 23.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('e948cf75e6b64307f7f76a49eaa9fc2f', None, nan, nan, nan, 2300.0, 36.0, 21.0, 36.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('83f86eca5473b6d1c7d566223592908d', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('541bc0bf3c3255ee2d44f3863336095e', None, nan, nan, nan, 4200.0, 64.0, 40.0, 48.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('beec9bc2305d3372fa3b3133ba3fd644', None, nan, nan, nan, 3000.0, 40.0, 40.0, 40.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('7285e977b36a2243203636b240772c5e', None, nan, nan, nan, 400.0, 25.0, 8.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('17823ffd2de8234f0e885a71109613a4', None, nan, nan, nan, 3750.0, 42.0, 20.0, 24.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('c230b471b7e21ff9060e68ee154afd70', None, nan, nan, nan, 200.0, 16.0, 5.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('fe34503c6bccf918db601aaafd4a975a', None, nan, nan, nan, 3000.0, 16.0, 21.0, 19.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('0c877471e35049402bca235e06cb8063', None, nan, nan, nan, 10750.0, 34.0, 20.0, 30.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('1574ed2c73e4465c572f68dd77528203', None, nan, nan, nan, 16000.0, 58.0, 28.0, 58.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('09ff539a621711667c43eba6a3bd8466', 'babies', 60.0, 865.0, 3.0, nan, nan, nan, nan)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('d2eb4e94aeb255a953cbd8b97361a848', None, nan, nan, nan, 300.0, 28.0, 28.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('8ef13bdd5d6da4bc50df1aaa486bf922', None, nan, nan, nan, 25800.0, 34.0, 84.0, 54.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('5a670fea12f6946f0dcb3fbb9728645d', None, nan, nan, nan, 600.0, 26.0, 3.0, 26.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('4ba237d0c64f22e4d22ec19af9cfd1f4', None, nan, nan, nan, 17100.0, 60.0, 40.0, 42.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('11f683ded5ddeecdad0b81b3124c3395', None, nan, nan, nan, 300.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('3d2d7eac865e47ff3939ea01aa56fb96', None, nan, nan, nan, 300.0, 16.0, 13.0, 13.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('5f5ee6e720308ce93007ce17c0835883', None, nan, nan, nan, 250.0, 20.0, 21.0, 16.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('67c4868694e75a87d7d0417c14fc26a3', None, nan, nan, nan, 400.0, 16.0, 16.0, 13.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('2aa23c51528b71a1c9f2ce72f4fc9ad8', None, nan, nan, nan, 200.0, 35.0, 4.0, 25.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('f52a0f70e54976873a4a7402349c6105', None, nan, nan, nan, 1500.0, 70.0, 4.0, 18.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b67444235c5d1da1b9e136f66fdf3fd0', None, nan, nan, nan, 7800.0, 37.0, 24.0, 34.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('ae4c65e3aee93bc068c671453b8aaea4', None, nan, nan, nan, 1300.0, 35.0, 35.0, 35.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('a14aea6067b93158e956612c50b74cfa', None, nan, nan, nan, 12900.0, 50.0, 30.0, 30.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('9246752373bd625f47da5e3d8b41b1dc', None, nan, nan, nan, 700.0, 20.0, 21.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b44922681ddcd1565a9d62932f20dcfe', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('2221e4ebc496addaa386a27a6a19e9b2', None, nan, nan, nan, 800.0, 29.0, 11.0, 23.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('1b1654fea0a8269f9ba9a1e1258edb61', None, nan, nan, nan, 150.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('c31d2c7898c24ea73ab60e0660fd693f', None, nan, nan, nan, 395.0, 26.0, 6.0, 18.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('7899001d8d8933d11d0f18ec5943f79e', None, nan, nan, nan, 1000.0, 29.0, 11.0, 14.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('1631507f13bd83d2f01e4fea424c852b', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('e43443a05db61acfccaca5876b804ba7', None, nan, nan, nan, 500.0, 30.0, 19.0, 18.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('e20be15ef3888b958c8a76a2f0edfc25', None, nan, nan, nan, 400.0, 25.0, 8.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('0b7fb806fe0194cc7eb473329c680e34', None, nan, nan, nan, 1000.0, 28.0, 11.0, 28.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('44d53f1240d6332232e4393c06500475', None, nan, nan, nan, 200.0, 16.0, 12.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('91fd85f0ce4e46aba09a5777469f4127', None, nan, nan, nan, 250.0, 22.0, 14.0, 14.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('8a26f391ab8b209f67d87dd358f6f004', None, nan, nan, nan, 2200.0, 24.0, 28.0, 24.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('e952feb7c657aae141c56f208088d511', None, nan, nan, nan, 600.0, 16.0, 30.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('1b930f20f389f3e3d057b9e3e85ca83d', None, nan, nan, nan, 600.0, 38.0, 5.0, 27.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('837f3d09b625825bd84bfccb1f51d8be', None, nan, nan, nan, 300.0, 20.0, 6.0, 26.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('76d1a1a9d21ab677a61c3ae34b1b352f', None, nan, nan, nan, 550.0, 16.0, 7.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('3bc5164bc7f4be77002d6651da65c98c', None, nan, nan, nan, 550.0, 16.0, 11.0, 19.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('e6d256dd10cfa8e1f36c0423d2b3adff', None, nan, nan, nan, 450.0, 20.0, 12.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('8d2ed4fec68ea93ec092cbab0e1a92b5', None, nan, nan, nan, 200.0, 16.0, 5.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('dc265762419b1b4a46eb0a242e713684', None, nan, nan, nan, 200.0, 35.0, 5.0, 25.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('882ae61d3259507f5c3ce5313f433651', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('5066fb9bf2b3db42c59f2f7732387249', None, nan, nan, nan, 380.0, 16.0, 4.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('51189083f547bae6df07c55c7b997001', None, nan, nan, nan, 3000.0, 30.0, 20.0, 30.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('f59062775ff63deba00e8b425f127e35', None, nan, nan, nan, 1400.0, 32.0, 36.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('704a6d9f35e39b53c509c886045329ef', None, nan, nan, nan, 400.0, 21.0, 8.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('ef60a683caacd212b1cc7b356283c2de', None, nan, nan, nan, 600.0, 16.0, 16.0, 16.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('0b3f73dba78abf4576c187092dc5dc81', None, nan, nan, nan, 1300.0, 30.0, 16.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('2873da054c3a30189c5aac7b87d3b6e9', None, nan, nan, nan, 1150.0, 40.0, 11.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('9e61de7e3ef7e99896060d76e48df65d', None, nan, nan, nan, 10700.0, 40.0, 40.0, 40.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('f92119d44c137a84ea866dc12df68407', None, nan, nan, nan, 3100.0, 30.0, 40.0, 30.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('75f54c6aa3a4ccb9ab44fae693c21418', None, nan, nan, nan, 850.0, 30.0, 24.0, 18.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('28b04f8634b7c9c6e3a41fbd0271e295', None, nan, nan, nan, 250.0, 28.0, 10.0, 23.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('f22ccf28078d6ba8961033bc6a20bc12', None, nan, nan, nan, 1500.0, 30.0, 10.0, 36.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('5d3e31adf8ff92075c3848f021abaf06', None, nan, nan, nan, 550.0, 16.0, 11.0, 23.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('7775d718fa8dfebe8015e6e5ee3dc5be', None, nan, nan, nan, 700.0, 16.0, 10.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('4e0d588f8e002f2bad9cbe0b8f66f6f6', None, nan, nan, nan, 200.0, 25.0, 5.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('13c68a908e3ec61b48544be41a74e8cd', None, nan, nan, nan, 6050.0, 50.0, 18.0, 40.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('2ddbeb76f134690c05636162f2558594', None, nan, nan, nan, 1400.0, 35.0, 10.0, 35.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('1b7384e0f9f5e4cb914cd3f5535a4cab', None, nan, nan, nan, 200.0, 16.0, 3.0, 12.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('3c59055b72a9160589590ca99611487e', None, nan, nan, nan, 150.0, 16.0, 16.0, 16.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('c60e25a5b45431b1c12be4d04bc9a7fa', None, nan, nan, nan, 8050.0, 50.0, 25.0, 37.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('45d0bf74166b507caa830564130b5ba0', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('17e7128a33dae59e32be411b7b4921b5', None, nan, nan, nan, 200.0, 20.0, 10.0, 16.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('d0fec025748a38a25d8f8adc72e874de', None, nan, nan, nan, 1100.0, 26.0, 10.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('6f6f3b1a96452e2fbad0cd4f7082765b', None, nan, nan, nan, 2600.0, 35.0, 33.0, 16.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('67f36b3689147d882d2b298fd0715d80', None, nan, nan, nan, 1200.0, 105.0, 10.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('0f4dbfe93fbadcce71e1edce3a3e30f0', None, nan, nan, nan, 153.0, 17.0, 14.0, 13.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('f7c7bd3105bd26ce0de4072af7159f84', None, nan, nan, nan, 890.0, 32.0, 32.0, 32.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('44483ca1c9223756ee0ee71c0676d3a3', None, nan, nan, nan, 1300.0, 18.0, 28.0, 18.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('df3a9e7f7f59298a2bf47cc0917dae1d', None, nan, nan, nan, 800.0, 23.0, 5.0, 31.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('2b29170916b7bbc58fd9078f0f4e7234', None, nan, nan, nan, 300.0, 50.0, 4.0, 40.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('3cc10293fcaadd63730fc96e8d136710', None, nan, nan, nan, 500.0, 20.0, 35.0, 35.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('d99e1e07cdfcb6400db4c4eef7b0b15b', None, nan, nan, nan, 200.0, 18.0, 6.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('c30302f36e15f43c1b85c9cb002028d5', None, nan, nan, nan, 300.0, 18.0, 15.0, 14.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('cdd63834cc3da0f9225cc20f494dc137', None, nan, nan, nan, 700.0, 25.0, 5.0, 19.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('c17abb4b4009c10138dec784ec61ba63', None, nan, nan, nan, 600.0, 18.0, 16.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('0538b3ea14af3cc3ee6bdaf940367cee', None, nan, nan, nan, 150.0, 20.0, 4.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('5605e265607c01c1242a18219d7e396e', None, nan, nan, nan, 2900.0, 70.0, 15.0, 50.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('fcb72602e3e6f59e5fdb5c3a4a3de410', None, nan, nan, nan, 8750.0, 36.0, 27.0, 54.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('dcea59ebbc38fcdee1974bbe56dc3755', None, nan, nan, nan, 1350.0, 28.0, 12.0, 28.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b72e2daf4a916d46eb0076071027d05b', None, nan, nan, nan, 150.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('e1da02256dce4dee2207c36853547c7b', None, nan, nan, nan, 7100.0, 27.0, 28.0, 35.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('e2613182a3d5b61459d52f24823134fb', None, nan, nan, nan, 1900.0, 20.0, 6.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('44dcb08478450d530b70de0c5c7c5f4a', None, nan, nan, nan, 1450.0, 40.0, 20.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('03706dca83513062fe74967a71b5fc78', None, nan, nan, nan, 400.0, 25.0, 8.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('212b9c1a73834eeae7694906e168edc6', None, nan, nan, nan, 450.0, 26.0, 7.0, 12.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('6962734c72522e70e852a2a77d21a730', None, nan, nan, nan, 10050.0, 62.0, 6.0, 62.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b0645512783cc56c9510f08e90a40ede', None, nan, nan, nan, 300.0, 20.0, 5.0, 25.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('ff6caf9340512b8bf6d2a2a6df032cfa', None, nan, nan, nan, 200.0, 16.0, 5.0, 12.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ...
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('92785d022b4e0e6b7cafc45f87a281fb', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('bc107cfd28a282c85b28e7054aeb729d', None, nan, nan, nan, 300.0, 18.0, 8.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('ad5f871bf1f82cf7aed349162ab802e6', None, nan, nan, nan, 1600.0, 24.0, 13.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('18da4a6d2c9b127b43ac8616ab151aa8', None, nan, nan, nan, 1300.0, 83.0, 4.0, 26.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('dfa3272f8e1bad4867677dfca2d061f3', None, nan, nan, nan, 2300.0, 34.0, 36.0, 32.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('0e030462875259ec0cb868f7ecf1fd5e', None, nan, nan, nan, 800.0, 17.0, 7.0, 13.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('e3c816666a7d2a1e7fbf02651e550b78', None, nan, nan, nan, 115.0, 16.0, 13.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('24b1fcad996ffb1ead90e324f264b783', None, nan, nan, nan, 200.0, 39.0, 9.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('2aba8009f50472b2eda33e9e2bb3ef6f', None, nan, nan, nan, 750.0, 19.0, 6.0, 26.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('dc8128d60372ee4869b22114e3bc4957', None, nan, nan, nan, 200.0, 25.0, 5.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('4cda9d93b0a846dfdca597f1b1d19c08', None, nan, nan, nan, 7300.0, 40.0, 40.0, 30.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('5f6ebc88683dcfc794febc8d8a8aeb0c', None, nan, nan, nan, 400.0, 16.0, 4.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('e82149ac02d9c909feccea6c879f4610', None, nan, nan, nan, 500.0, 20.0, 15.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b8c2cf7e813b0eb7ec62f7459217b22c', None, nan, nan, nan, 1800.0, 40.0, 23.0, 13.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('ba71302e3a8b2129024487a3e54bc2fa', None, nan, nan, nan, 400.0, 30.0, 30.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('5a848e4ab52fd5445cdc07aab1c40e48', None, nan, nan, nan, 400.0, 20.0, 12.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('584d2812194b6a09a05bb9106009b473', None, nan, nan, nan, 14300.0, 70.0, 30.0, 50.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('65ab2b4e40425acec6125e3d48919b2e', None, nan, nan, nan, 1850.0, 31.0, 30.0, 28.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('88c09dd121ebe0b119a759773d405cc4', None, nan, nan, nan, 300.0, 22.0, 9.0, 16.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('8ae1fefcfdc30ea49de246665b6d2713', None, nan, nan, nan, 400.0, 16.0, 15.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('83a837a76c0753d44c7c12bcb1b96158', None, nan, nan, nan, 200.0, 25.0, 5.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('abe135ae574a8969994de86975004972', None, nan, nan, nan, 900.0, 26.0, 18.0, 18.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b0c025bfe73a24057cb15eeab19ebdf2', None, nan, nan, nan, 400.0, 16.0, 9.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('5cebe3c91f03e5d52a1951b3ce8354cd', None, nan, nan, nan, 1000.0, 22.0, 21.0, 23.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('f71a7ef227514bb1feacf612102d6a19', None, nan, nan, nan, 800.0, 50.0, 15.0, 30.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('24776376f3b02d27ac141a1bdc46d628', None, nan, nan, nan, 200.0, 17.0, 14.0, 16.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('4a411619ffbd1bb6180c44ca6e16639d', None, nan, nan, nan, 800.0, 16.0, 19.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('3895c3901baeb3589ea9acd2ded5e2a4', None, nan, nan, nan, 200.0, 16.0, 2.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('d36c8237f8a0a889aa9d6ac7816097e3', None, nan, nan, nan, 8750.0, 80.0, 10.0, 60.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('2d188e4d3435b1bf29dfd385b324de2c', None, nan, nan, nan, 800.0, 39.0, 12.0, 17.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b690fe3d3dd6223b85382ccca04ffbde', None, nan, nan, nan, 300.0, 16.0, 8.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('18aae9918a7e1d46e0c94c63a756c97c', None, nan, nan, nan, 700.0, 16.0, 12.0, 12.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('090820212dfd8022d676e480bed6a61d', None, nan, nan, nan, 250.0, 16.0, 4.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('6bda3bc4a9032dc7f18b635e051d0c72', None, nan, nan, nan, 2300.0, 47.0, 23.0, 32.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('cbe24747d52ccb72f4fd7190c41aff73', None, nan, nan, nan, 800.0, 16.0, 24.0, 16.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('41eee23c25f7a574dfaf8d5c151dbb12', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('4432acdc80e1b1f73f9f355f12ecd60f', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('2fc46e8ba9bbe4d062776e585b8c0057', None, nan, nan, nan, 700.0, 19.0, 28.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('4914f8796af2ecd359fd8f44b9b92339', None, nan, nan, nan, 100.0, 16.0, 11.0, 12.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('980a05f1865790c75cf9a22ae4771c1c', None, nan, nan, nan, 21700.0, 40.0, 50.0, 50.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('4754922e24570093f580454e5920cd34', None, nan, nan, nan, 700.0, 16.0, 18.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('5368f8caaa939da050e8dfd7d08fde62', None, nan, nan, nan, 150.0, 16.0, 12.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('3fc7f2008dc11b252c0f0e51a7bea4d6', None, nan, nan, nan, 600.0, 40.0, 6.0, 30.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('ae91ef458ab29ff95a0defb53fa030e9', None, nan, nan, nan, 500.0, 16.0, 3.0, 12.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b7f980dbd49d4059a8c4acbada394e4b', None, nan, nan, nan, 400.0, 16.0, 7.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('7a81b0d1231e9ed0c2ff4237f49e5dc0', None, nan, nan, nan, 100.0, 16.0, 5.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('baded889837476e342ac1e93c87ce383', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('d4959e4f53f19c94abec965e966c7ca9', None, nan, nan, nan, 1200.0, 20.0, 20.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('661e3bba6bdb874638367462b49ae590', None, nan, nan, nan, 450.0, 30.0, 5.0, 30.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('c09d788af5101df1f542712d2968d4df', None, nan, nan, nan, 8500.0, 23.0, 16.0, 24.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('ace8fb267a4f76c58dad79d0171f6812', None, nan, nan, nan, 26950.0, 65.0, 79.0, 29.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('e034d967d446f193a9d72f30a282c312', None, nan, nan, nan, 900.0, 20.0, 10.0, 12.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('2cd7d0ade9eb52c856a16dce303397ad', None, nan, nan, nan, 200.0, 27.0, 3.0, 18.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('6f3ec6fc14615aaed51a2e900868a3cf', None, nan, nan, nan, 600.0, 20.0, 10.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('aa52785e49f7b78b96704df4068d9e3d', None, nan, nan, nan, 250.0, 16.0, 8.0, 16.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('0ba14c257ad706bacadec65dfdb3b740', None, nan, nan, nan, 300.0, 16.0, 10.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('bfa0e398bef2d28bb421d42997982cab', None, nan, nan, nan, 3100.0, 28.0, 20.0, 40.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('d5376c3b45290c7a326584c8307ab2c4', None, nan, nan, nan, 16550.0, 58.0, 32.0, 32.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b1d207586fca400a2370d50a9ba1da98', None, nan, nan, nan, 350.0, 16.0, 4.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b91982b3afff5d274cf34ce54801a8e6', None, nan, nan, nan, 1500.0, 50.0, 30.0, 32.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('9689d8153681f3d8bc3e88622c013b08', None, nan, nan, nan, 300.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('fbb1cfc2810efabf3235eccf4530f4ae', None, nan, nan, nan, 800.0, 35.0, 15.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('bff35d3572b474e918bb0780723240bb', None, nan, nan, nan, 600.0, 30.0, 30.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('8e49e2b4aaa2a78f82c80d2e488084f6', None, nan, nan, nan, 1500.0, 35.0, 33.0, 47.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('0bb7d5c406dd6affef3cd4f5d6744844', None, nan, nan, nan, 200.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('ba4a6f5b128eec53f68288f5238f9971', None, nan, nan, nan, 2100.0, 36.0, 16.0, 46.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('5b736e2bc208fe225a4f3da85e5dc63d', None, nan, nan, nan, 175.0, 38.0, 22.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('89dacd5290cff31247fa3e2412c08e02', None, nan, nan, nan, 1100.0, 27.0, 9.0, 35.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('4c50dcc50f1512f46096d6ef0142c4a9', None, nan, nan, nan, 800.0, 16.0, 2.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('8d0e7a8e1b1fb5343135045cb7c21542', None, nan, nan, nan, 1800.0, 26.0, 25.0, 47.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('bb1c86c0b1cd8da99fbd48d798abcca0', None, nan, nan, nan, 830.0, 19.0, 6.0, 26.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('338f1838eb9cd29b59c9c2f4ee158f15', None, nan, nan, nan, 250.0, 16.0, 4.0, 11.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('8a27d3427a61686ec37357b5ccf24425', None, nan, nan, nan, 800.0, 21.0, 12.0, 15.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('9549bc9cccdcfb09de0bd4774b018c3d', None, nan, nan, nan, 3000.0, 40.0, 29.0, 29.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b2545dd62c61d45d55ebaa04d1cb1e23', None, nan, nan, nan, 1475.0, 42.0, 24.0, 31.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('d886830f276eaa72305b18639bc4cfce', None, nan, nan, nan, 1800.0, 25.0, 25.0, 25.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('22e8a1571e0f8e1aeac77c01ae28539c', None, nan, nan, nan, 1300.0, 17.0, 25.0, 20.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('b0a0c5dd78e644373b199380612c350a', None, nan, nan, nan, 1800.0, 30.0, 20.0, 70.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('10dbe0fbaa2c505123c17fdc34a63c56', None, nan, nan, nan, 800.0, 30.0, 10.0, 23.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('bd2ada37b58ae94cc838b9c0569fecd8', None, nan, nan, nan, 200.0, 21.0, 8.0, 16.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('fa51e914046aab32764c41356b9d4ea4', None, nan, nan, nan, 1300.0, 45.0, 16.0, 45.0)
# ❌ Error inserting into `products`: 1054 (42S22): Unknown column 'nan' in 'field list'
# ⛔ Problematic row: ('c4ceee876c82b8328e9c293fa0e1989b', None, nan, nan, nan, 700.0, 28.0, 3.0, 43.0)
# ✅ Inserted 32340 records into `products`.
#
# ⚠️ File not found: E:/Data Analysis/E-Commerce/Dataset\delivery.csv
# 📥 Processing: payments.csv
# 📊 Columns in `payments`: ['order_id', 'payment_sequential', 'payment_type', 'payment_installments', 'payment_value']
# ✅ Inserted 103886 records into `payments`.
#
# 📥 Processing: order_items.csv
# 📊 Columns in `order_items`: ['order_id', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'price', 'freight_value']
# ✅ Inserted 112650 records into `order_items`.
#
# 🎉 All done! MySQL connection closed.

# %%
import pandas as pd
import mysql.connector
import os

# List of CSV files and their corresponding table names
csv_files = [
   ('customers.csv', 'customers'),
    ('orders.csv', 'orders'),
    ('sellers.csv', 'sellers'),
    ('products.csv', 'products'),
    ('geolocation.csv', 'geolocation'),
    ('payments.csv', 'payments'),
    ('order_items.csv', 'order_items')  # Added payments.csv for specific handling
]

# Connect to the MySQL database
conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='Bhanu0843@',
    database='ecommerce'
)
cursor = conn.cursor()

# Folder containing the CSV files
folder_path = 'E:/Data Analysis/E-Commerce/Dataset'

def get_sql_type(dtype):
    if pd.api.types.is_integer_dtype(dtype):
        return 'INT'
    elif pd.api.types.is_float_dtype(dtype):
        return 'FLOAT'
    elif pd.api.types.is_bool_dtype(dtype):
        return 'BOOLEAN'
    elif pd.api.types.is_datetime64_any_dtype(dtype):
        return 'DATETIME'
    else:
        return 'TEXT'

for csv_file, table_name in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    
    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv(file_path)
    
    # Replace NaN with None to handle SQL NULL
    df = df.where(pd.notnull(df), None)
    
    # Debugging: Check for NaN values
    print(f"Processing {csv_file}")
    print(f"NaN values before replacement:\n{df.isnull().sum()}\n")

    # Clean column names
    df.columns = [col.replace(' ', '_').replace('-', '_').replace('.', '_') for col in df.columns]

    # Generate the CREATE TABLE statement with appropriate data types
    columns = ', '.join([f'`{col}` {get_sql_type(df[col].dtype)}' for col in df.columns])
    create_table_query = f'CREATE TABLE IF NOT EXISTS `{table_name}` ({columns})'
    cursor.execute(create_table_query)

    # Insert DataFrame data into the MySQL table
    for _, row in df.iterrows():
        # Convert row to tuple and handle NaN/None explicitly
        values = tuple(None if pd.isna(x) else x for x in row)
        sql = f"INSERT INTO `{table_name}` ({', '.join(['`' + col + '`' for col in df.columns])}) VALUES ({', '.join(['%s'] * len(row))})"
        cursor.execute(sql, values)

    # Commit the transaction for the current CSV file
    conn.commit()

# Close the connection
conn.close()
# Out:
# Processing customers.csv
# NaN values before replacement:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
#
# Processing orders.csv
# NaN values before replacement:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64
#
# Processing sellers.csv
# NaN values before replacement:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64
#
# Processing products.csv
# NaN values before replacement:
# product_id                      0
# product category              610
# product_name_length           610
# product_description_length    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 44
#      41 file_path = os.path.join(folder_path, csv_file)
#      43 # Read the CSV file into a pandas DataFrame
# ---> 44 df = pd.read_csv(file_path)
#      46 # Replace NaN with None to handle SQL NULL
#      47 df = df.where(pd.notnull(df), None)
#
# File e:\Data Analysis\E-Commerce\venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File e:\Data Analysis\E-Commerce\venv\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File e:\Data Analysis\E-Commerce\venv\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File e:\Data Analysis\E-Commerce\venv\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File e:\Data Analysis\E-Commerce\venv\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:/Data Analysis/E-Commerce/Dataset\\delivery.csv'
